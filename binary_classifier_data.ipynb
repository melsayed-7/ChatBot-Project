# %% [markdown]
# <a href="https://colab.research.google.com/github/moustafa-7/ChatBot-Project/blob/master/binary_classifier_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget --header="Host: doc-0g-4s-docs.googleusercontent.com" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3" --header="Accept-Language: en-US,en;q=0.9" --header="Referer: https://drive.google.com/" --header="Cookie: AUTH_kahsjga3le6prgc14cd9quo9442oc1jl_nonce=1chdsjk9oktgu; _ga=GA1.2.1326684588.1554576252" --header="Connection: keep-alive" "https://doc-0g-4s-docs.googleusercontent.com/docs/securesc/6e55a1dr750nd4vfil7uefcrohjkedpb/ru7p4f5akt1jgo5s4mf6vb0mnecbq8o4/1561305600000/17276416090818950573/07423407162889017215/1JBnuP1GTXvhiTb80OEzN13uV7wMLkktg?e=download&nonce=1chdsjk9oktgu&user=07423407162889017215&hash=moaa7m54vl1edep2idr8c1824mfm2vo1" -O "binary_classifier_data.zip" -c

# %%
# !unzip binary_classifier_data.zip -d data
# Out:
# Archive:  binary_classifier_data.zip
#   inflating: data/training.csv
#   inflating: data/validation.csv

# %%
import pandas as pd 
import sklearn

# %%
df = pd.read_csv("data/training.csv",sep = ";")

# %%
df = df.drop(columns = "variable18")

# %%
df
# Out:
#      variable1 variable2  variable3  ... variable17 variable19 classLabel
# 0            a     17,92    5,4e-05  ...   800000.0          0        no.
# 1            b     16,92   3,35e-05  ...  2000000.0          0        no.
# 2            b     31,25  0,0001125  ...   960000.0          0        no.
# 3            a     48,17  0,0001335  ...        0.0          0        no.
# 4            b     32,33    0,00035  ...  2320000.0          0        no.
# 5            a     34,83   0,000125  ...  1600000.0          0        no.
# 6            a     26,17      2e-04  ...  2760000.0          0        no.
# 7            b     21,17   8,75e-05  ...  2800000.0          0        no.
# 8            b     28,92   3,75e-05  ...  2200000.0          0        no.
# 9            b     18,17   0,001025  ...  3200000.0          0        no.
# 10           a     24,75  0,0013665  ...  2800000.0          0        no.
# 11           a     31,75      3e-04  ...  1600000.0          0        no.
# ...

# %%
# The data was separated some with ; and some with , couldn't get any description of the data so had hard time knowing how to deal with it
# I do a lot of Natural language processing but not a lot with tabular data so couldn't exactly deal with this task


# Check the conversational deep learning model chatbot.
# https://github.com/moustafa-7/ChatBot-Project

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

x = df.iloc[:,:-1].values
y = df.iloc[:,17].values


from sklearn.preprocessing import Imputer

imputer = Imputer(missing_values = 'NaN', strategy = 'mean', axis =0)
x[:,:-1] = imputer.fit_transform(x[:,:-1])

from sklearn.preprocessing import LabelEncoder
label_encoder_x = LabelEncoder()

X[:,0] = label_encoder_x.fit_transform(X[:,0])
X[:,3] = label_encoder_x.fit_transform(X[:,3])
X[:,4] = label_encoder_x.fit_transform(X[:,4])
X[:,5] = label_encoder_x.fit_transform(X[:,5])
X[:,6] = label_encoder_x.fit_transform(X[:,6])
X[:,8] = label_encoder_x.fit_transform(X[:,8])
X[:,9] = label_encoder_x.fit_transform(X[:,9])
X[:,11] = label_encoder_x.fit_transform(X[:,11])
X[:,12] = label_encoder_x.fit_transform(X[:,12])
X[:,12] = label_encoder_x.fit_transform(X[:,12])
X[:,17] = label_encoder_x.fit_transform(X[:,17])
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-fe136877bf5f> in <module>()
#      12
#      13 imputer = Imputer(missing_values = 'NaN', strategy = 'mean', axis =0)
# ---> 14 x[:,:-1] = imputer.fit_transform(x[:,:-1])
#      15
#      16 from sklearn.preprocessing import LabelEncoder
#
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     551         if y is None:
#     552             # fit method of arity 1 (unsupervised transformation)
# --> 553             return self.fit(X, **fit_params).transform(X)
# ...
